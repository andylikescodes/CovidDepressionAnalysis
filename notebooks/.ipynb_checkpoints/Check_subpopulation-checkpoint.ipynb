# %%
import pandas as pd
import numpy as np

# %%
data_all_imputed = "../data/data_all_impute.csv"

# %%
data = pd.read_csv(data_all_imputed, index_col=0)
# Out:
# C:\Users\andyl\anaconda3\envs\g\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (196,208,212,216,223,243,264,268,270,271,290,297,305,343,362,369,379,542,706,723,724,725,726,727,728,729,730,731,732,733,734,766,768) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # TODOs:

# %% [markdown]
# 1. Frederick requested us to run the code and analysis also for anxiety and stress to see if we can identify the effect.
# 2. Check some subpopulation and see if there are effects there.
# 3. Check the individual level, aligned the subjects to time points when the restrictions are lifted.

# %% [markdown]
# # Do we have have differences in subpopulations for depression?

# %% [markdown]
# Looking at the NEO-FFI big five right now: https://www-sciencedirect-com.libproxy.chapman.edu/science/article/pii/S0191886999002421
#
# So what we want to do is to understand about the big 5 and see if we can potentially see the different

# %%
data.keys().to_list()
# Out:
# ['PROLIFIC_PID',
#  'wave',
#  'Fear_COVID_raw',
#  'Disgust_COVID_raw',
#  'DISG1.1_20',
#  'DISG1.1_22',
#  'DISG1.2_15',
#  'DISG1.2_17',
#  'DISG1.2_18',
#  'DISG1.2_19',
#  'DISG1.2_20',
#  'DISG1.2_21',
#  'DISG1.2_22',
#  'Fear2_1',
#  'Fear2_2',
#  'Fear2_3',
#  'Fear2_4',
#  'Fear2_5',
#  'Fear2_6',
#  'Fear2_7',
#  'DO-Q-DISG1.1',
#  'DO-Q-DISG1.2',
#  'DO-Q-DISG2.1',
#  'DO-Q-DISG2.2',
#  'DO-Q-Fear2',
#  'STAI_State_raw',
#  'STAI_State_Tscore',
#  'STAI_Trait_raw',
#  'STAI_Trait_Tscore',
#  'AnxS1_1',
#  'AnxS1_2',
#  'AnxS1_3',
#  'AnxS1_4',
#  'AnxS1_5',
#  'AnxS1_6',
#  'AnxS1_7',
#  'AnxS1_8',
#  'AnxS1_9',
#  'AnxS1_10',
#  'AnxS1_11',
#  'AnxS1_12',
#  'AnxS1_13',
#  'AnxS1_14',
#  'AnxS1_15',
#  'AnxS1_16',
#  'AnxS1_17',
#  'AnxS1_18',
#  'AnxS1_19',
#  'AnxS1_20',
#  'AnxT_1',
#  'AnxT_2',
#  'AnxT_3',
#  'AnxT_4',
#  'AnxT_5',
#  'AnxT_6',
#  'AnxT_7',
#  'AnxT_8',
#  'AnxT_9',
#  'AnxT_10',
#  'AnxT_11',
#  'AnxT_12',
#  'AnxT_13',
#  'AnxT_14',
# ...
